# %%
import numpy as np
import Scripts.cifar_resnet as rn
import Scripts.wake_processing as wp
import importlib
import Scripts.autoencoder as ae
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from tqdm import tqdm
from collections import Counter
# %matplotlib inline

# %%
importlib.reload(rn)
importlib.reload(wp)
# Out:
# <module 'Scripts.wake_processing' from 'E:\\Studies\\Deep Water\\DeepWater\\Scripts\\wake_processing.py'>

# %% [markdown]
# ## Training Data

# %%
real_wakes_data = np.load("Data\\Wake data\\confirmed_wakes.npy")
generated_wakes = np.load("Data\\Wake data\\generated_wakes_1000.npy")
not_wakes_day_data = np.load("Data\\Wake data\\negative_samples_3000_day.npy")
not_wakes_all_data = np.load("Data\\Wake data\\negative_samples_3000.npy")
real_wakes = real_wakes_data[:,:,:-1,:]
not_wakes = not_wakes_day_data[:,:,:-1,:]
not_wakes_all = not_wakes_day_data[:,:,:-1,:]

# %% [markdown]
# ## Temp

# %%
wp.make_heatmap(generated_wakes[0,3,:,:], None, save = True, filename = "Wake Figures//generated_wake_sample.png")

# %%
#wp.make_heatmap(wake_samples[141,3,:-1,:], wake_samples[141,3,-1,:], save = True, filename = "Wake Figures/wake_sample.png")

# %% [markdown]
# ## Train function

# %%
def train_rn(model, train_data, test_data, num_epochs=5, batch_size=5, learning_rate=1e-3):
    model = model.to(device)
    torch.manual_seed(0)
    criterion = nn.BCELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)
    train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size, num_workers=0, drop_last=True)
    X_val, y_val = test_data.tensors[0].to(device), test_data.tensors[1].to(device)
    train_losses = []
    val_losses = []
    val_accs = []
    train_accs= []
    for epoch in range(num_epochs):
        total_loss = []
        batch_accs = []
        for i, (X, y) in enumerate(train_loader):
            X = X.to(device)
            y = y.to(device)
            pred = model(X)
            loss = criterion(pred, y)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            train_pred_label = 1 - torch.argmax(pred, dim = 1).cpu().detach().numpy()
            train_true_label = 1 - torch.argmax(y, dim = 1).cpu().detach().numpy()
            batch_acc = accuracy_score(train_true_label, train_pred_label)
            batch_accs.append(batch_acc)
            total_loss.append(loss.item())
            
        val_pred = model(X_val)
        val_pred_label = 1 - torch.argmax(val_pred, dim = 1).cpu().detach().numpy()
        val_true_label = 1 - torch.argmax(y_val, dim = 1).cpu().detach().numpy()
        val_loss = criterion(val_pred, y_val).item()
        train_loss = sum(total_loss)/len(total_loss)
        train_acc = sum(batch_accs)/len(batch_accs)
        val_acc = accuracy_score(val_true_label, val_pred_label)
        print('Epoch:{}, Loss:{:.4f}, Val Loss:{:.4f}, Train Acc:{:4f}, Val Acc:{:.4f}'.format(epoch+1, train_loss,
                                                                                               val_loss, train_acc, val_acc))
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        train_accs.append(train_acc)
    return train_losses, val_losses, train_accs, val_accs

# %%
def make_plots(train_losses, val_losses, train_accs, val_accs):
    plt.figure(figsize=(10,6))
    plt.plot(train_losses, label = 'Train loss')
    plt.plot(val_losses, label = 'Validation loss')
    plt.legend(loc = 'upper left')
    plt.xlabel('Epoch')
    plt.ylabel('Binary Cross-entropy loss')
    plt.show()
    plt.figure(figsize=(10,6))
    plt.plot(train_accs, label = 'Train accuracy')
    plt.plot(val_accs, label = 'Validation accuracy')
    plt.legend(loc = 'upper left')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.show()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 25

# %%
RS = 1

# %% [markdown]
# ## Experiment 1
# ### Training: 500 positive (113 real + 387 generated) and 500 negative
# ### Test: 75 positive (29 real + 46 generated) and 75 negative

# %%
train_real, test_real = train_test_split(real_wakes, test_size=0.2, random_state=RS)
train_gen, test_gen = train_test_split(generated_wakes, train_size = 0.387, test_size=0.046, random_state=RS)
train_neg, test_neg = train_test_split(not_wakes, train_size = 1/6, test_size = 75/3000, random_state = RS)

# %%
test_pos = np.append(test_real, test_gen, axis = 0)
train_pos = np.append(train_real, train_gen, axis = 0)
test_x = np.append(test_pos, test_neg, axis = 0)
train_x = np.append(train_pos, train_neg, axis = 0)
test_pos_y = np.concatenate((np.ones(test_pos.shape[0]).reshape(-1,1), np.zeros(test_pos.shape[0]).reshape(-1,1)), axis = 1)
test_neg_y = np.concatenate((np.zeros(test_neg.shape[0]).reshape(-1,1), np.ones(test_neg.shape[0]).reshape(-1,1)), axis = 1)
train_pos_y = np.concatenate((np.ones(train_pos.shape[0]).reshape(-1,1), np.zeros(train_pos.shape[0]).reshape(-1,1)), axis = 1)
train_neg_y = np.concatenate((np.zeros(train_neg.shape[0]).reshape(-1,1), np.ones(train_neg.shape[0]).reshape(-1,1)), axis = 1)
test_y = np.append(test_pos_y, test_neg_y, axis = 0)
test_y_exp_1 = test_y
test_x_exp_1 = test_x
train_y = np.append(train_pos_y, train_neg_y, axis = 0)

# %%
train_dataset = TensorDataset(torch.Tensor(train_x), torch.Tensor(train_y))
test_dataset = TensorDataset(torch.Tensor(test_x), torch.Tensor(test_y))

# %%
resnet_1 = None
resnet_1 = rn.ResNet18()
train_losses, val_losses, train_accs, val_accs = train_rn(resnet_1, train_dataset, test_dataset, num_epochs = num_epochs, learning_rate=1e-4)
# Out:
# Epoch:1, Loss:0.3141, Val Loss:0.2381, Train Acc:0.860000, Val Acc:0.9267
# Epoch:2, Loss:0.2013, Val Loss:0.2012, Train Acc:0.922000, Val Acc:0.9467
# Epoch:3, Loss:0.1366, Val Loss:0.2386, Train Acc:0.953000, Val Acc:0.9267
# Epoch:4, Loss:0.0738, Val Loss:0.2337, Train Acc:0.976000, Val Acc:0.9400
# Epoch:5, Loss:0.0745, Val Loss:0.1865, Train Acc:0.971000, Val Acc:0.9467
# Epoch:6, Loss:0.0303, Val Loss:0.2050, Train Acc:0.992000, Val Acc:0.9333
# Epoch:7, Loss:0.0166, Val Loss:0.2568, Train Acc:0.996000, Val Acc:0.9267
# Epoch:8, Loss:0.0175, Val Loss:0.2475, Train Acc:0.995000, Val Acc:0.9400
# Epoch:9, Loss:0.0930, Val Loss:0.1891, Train Acc:0.967000, Val Acc:0.9533
# Epoch:10, Loss:0.0118, Val Loss:0.1734, Train Acc:0.997000, Val Acc:0.9400
# Epoch:11, Loss:0.0320, Val Loss:0.2524, Train Acc:0.986000, Val Acc:0.9133
# Epoch:12, Loss:0.0405, Val Loss:0.1878, Train Acc:0.988000, Val Acc:0.9400
# Epoch:13, Loss:0.0116, Val Loss:0.3760, Train Acc:0.997000, Val Acc:0.9333
# Epoch:14, Loss:0.0031, Val Loss:0.2534, Train Acc:1.000000, Val Acc:0.9467
# Epoch:15, Loss:0.0010, Val Loss:0.2839, Train Acc:1.000000, Val Acc:0.9467
# Epoch:16, Loss:0.0004, Val Loss:0.2990, Train Acc:1.000000, Val Acc:0.9467
# Epoch:17, Loss:0.0004, Val Loss:0.3210, Train Acc:1.000000, Val Acc:0.9467
# Epoch:18, Loss:0.0003, Val Loss:0.3067, Train Acc:1.000000, Val Acc:0.9467
# Epoch:19, Loss:0.0002, Val Loss:0.3255, Train Acc:1.000000, Val Acc:0.9467
# Epoch:20, Loss:0.0001, Val Loss:0.3307, Train Acc:1.000000, Val Acc:0.9467
# Epoch:21, Loss:0.0001, Val Loss:0.3412, Train Acc:1.000000, Val Acc:0.9467
# Epoch:22, Loss:0.0002, Val Loss:0.3480, Train Acc:1.000000, Val Acc:0.9400
# Epoch:23, Loss:0.0001, Val Loss:0.3332, Train Acc:1.000000, Val Acc:0.9533
# Epoch:24, Loss:0.0001, Val Loss:0.3316, Train Acc:1.000000, Val Acc:0.9533
# Epoch:25, Loss:0.0001, Val Loss:0.3342, Train Acc:1.000000, Val Acc:0.9533

# %%
make_plots(train_losses, val_losses, train_accs, val_accs)

# %% [markdown]
# ## Experiment 2
# ### Training: 200 positive (113 real + 87 generated) and 800 negative
# ### Test: 75 positive (29 real + 46 generated) and 75 negative

# %%
train_real, test_real = train_test_split(real_wakes, test_size=0.2, random_state=RS)
train_gen, test_gen = train_test_split(generated_wakes, train_size = 0.087, test_size=0.046, random_state=RS)
train_neg, test_neg = train_test_split(not_wakes, train_size = 800/3000, test_size = 75/3000, random_state = RS)
test_pos = np.append(test_real, test_gen, axis = 0)
train_pos = np.append(train_real, train_gen, axis = 0)
test_x = np.append(test_pos, test_neg, axis = 0)
train_x = np.append(train_pos, train_neg, axis = 0)
test_pos_y = np.concatenate((np.ones(test_pos.shape[0]).reshape(-1,1), np.zeros(test_pos.shape[0]).reshape(-1,1)), axis = 1)
test_neg_y = np.concatenate((np.zeros(test_neg.shape[0]).reshape(-1,1), np.ones(test_neg.shape[0]).reshape(-1,1)), axis = 1)
train_pos_y = np.concatenate((np.ones(train_pos.shape[0]).reshape(-1,1), np.zeros(train_pos.shape[0]).reshape(-1,1)), axis = 1)
train_neg_y = np.concatenate((np.zeros(train_neg.shape[0]).reshape(-1,1), np.ones(train_neg.shape[0]).reshape(-1,1)), axis = 1)
test_y = np.append(test_pos_y, test_neg_y, axis = 0)
train_y = np.append(train_pos_y, train_neg_y, axis = 0)
train_dataset = TensorDataset(torch.Tensor(train_x), torch.Tensor(train_y))
test_dataset = TensorDataset(torch.Tensor(test_x), torch.Tensor(test_y))

# %%
test_dataset.tensors[0].shape
# Out:
# torch.Size([150, 4, 28, 60])

# %%
resnet_2 = None
resnet_2 = rn.ResNet18()
train_losses, val_losses, train_accs, val_accs = train_rn(resnet_2, train_dataset, test_dataset, num_epochs = num_epochs, learning_rate=1e-4)
# Out:
# Epoch:1, Loss:0.3057, Val Loss:0.3009, Train Acc:0.869000, Val Acc:0.8733
# Epoch:2, Loss:0.2128, Val Loss:0.2821, Train Acc:0.926000, Val Acc:0.9067
# Epoch:3, Loss:0.1486, Val Loss:0.3137, Train Acc:0.953000, Val Acc:0.8733
# Epoch:4, Loss:0.1190, Val Loss:0.2350, Train Acc:0.965000, Val Acc:0.9133
# Epoch:5, Loss:0.0802, Val Loss:0.2329, Train Acc:0.976000, Val Acc:0.9200
# Epoch:6, Loss:0.0708, Val Loss:0.3000, Train Acc:0.977000, Val Acc:0.9067
# Epoch:7, Loss:0.0448, Val Loss:0.1778, Train Acc:0.985000, Val Acc:0.9400
# Epoch:8, Loss:0.0631, Val Loss:0.3201, Train Acc:0.979000, Val Acc:0.9267
# Epoch:9, Loss:0.0553, Val Loss:0.3007, Train Acc:0.979000, Val Acc:0.9133
# Epoch:10, Loss:0.0117, Val Loss:0.2836, Train Acc:0.997000, Val Acc:0.9467
# Epoch:11, Loss:0.0016, Val Loss:0.3041, Train Acc:1.000000, Val Acc:0.9467
# Epoch:12, Loss:0.0011, Val Loss:0.2949, Train Acc:1.000000, Val Acc:0.9533
# Epoch:13, Loss:0.0013, Val Loss:0.2035, Train Acc:1.000000, Val Acc:0.9533
# Epoch:14, Loss:0.1157, Val Loss:0.4243, Train Acc:0.964000, Val Acc:0.8933
# Epoch:15, Loss:0.0580, Val Loss:0.4312, Train Acc:0.979000, Val Acc:0.8867
# Epoch:16, Loss:0.0379, Val Loss:0.4611, Train Acc:0.985000, Val Acc:0.8933
# Epoch:17, Loss:0.0138, Val Loss:0.2893, Train Acc:0.997000, Val Acc:0.9333
# Epoch:18, Loss:0.0049, Val Loss:0.3459, Train Acc:0.999000, Val Acc:0.9133
# Epoch:19, Loss:0.0367, Val Loss:0.2371, Train Acc:0.984000, Val Acc:0.9600
# Epoch:20, Loss:0.0093, Val Loss:0.3072, Train Acc:0.999000, Val Acc:0.9467
# Epoch:21, Loss:0.0017, Val Loss:0.3138, Train Acc:1.000000, Val Acc:0.9467
# Epoch:22, Loss:0.0006, Val Loss:0.3054, Train Acc:1.000000, Val Acc:0.9467
# Epoch:23, Loss:0.0003, Val Loss:0.2969, Train Acc:1.000000, Val Acc:0.9533
# Epoch:24, Loss:0.0003, Val Loss:0.3082, Train Acc:1.000000, Val Acc:0.9533
# Epoch:25, Loss:0.0003, Val Loss:0.2928, Train Acc:1.000000, Val Acc:0.9533

# %%
make_plots(train_losses, val_losses, train_accs, val_accs)

# %% [markdown]
# ## Experiment 3
# ### Training: 100 positive (100 real) and 900 negative
# ### Test: 75 positive (29 real + 46 generated) and 75 negative

# %%
train_real, test_real = train_test_split(real_wakes, train_size = 100/142, test_size=0.2, random_state=RS)
train_gen, test_gen = train_test_split(generated_wakes, train_size = 0.087, test_size=0.046, random_state=RS)
train_neg, test_neg = train_test_split(not_wakes, train_size = 900/3000, test_size = 75/3000, random_state = RS)
test_pos = np.append(test_real, test_gen, axis = 0)
train_pos = train_real
#train_pos = np.append(train_real, train_gen, axis = 0)
test_x = np.append(test_pos, test_neg, axis = 0)
train_x = np.append(train_pos, train_neg, axis = 0)
test_pos_y = np.concatenate((np.ones(test_pos.shape[0]).reshape(-1,1), np.zeros(test_pos.shape[0]).reshape(-1,1)), axis = 1)
test_neg_y = np.concatenate((np.zeros(test_neg.shape[0]).reshape(-1,1), np.ones(test_neg.shape[0]).reshape(-1,1)), axis = 1)
train_pos_y = np.concatenate((np.ones(train_pos.shape[0]).reshape(-1,1), np.zeros(train_pos.shape[0]).reshape(-1,1)), axis = 1)
train_neg_y = np.concatenate((np.zeros(train_neg.shape[0]).reshape(-1,1), np.ones(train_neg.shape[0]).reshape(-1,1)), axis = 1)
test_y = np.append(test_pos_y, test_neg_y, axis = 0)
train_y = np.append(train_pos_y, train_neg_y, axis = 0)
train_dataset = TensorDataset(torch.Tensor(train_x), torch.Tensor(train_y))
test_dataset = TensorDataset(torch.Tensor(test_x), torch.Tensor(test_y))

# %%
train_dataset.tensors[0].shape
# Out:
# torch.Size([1000, 4, 28, 60])

# %%
resnet_3 = None
resnet_3 = rn.ResNet18()
train_losses, val_losses, train_accs, val_accs = train_rn(resnet_3, train_dataset, test_dataset, num_epochs = num_epochs, learning_rate=1e-4)
# Out:
# Epoch:1, Loss:0.2293, Val Loss:0.7360, Train Acc:0.927000, Val Acc:0.7000
# Epoch:2, Loss:0.1573, Val Loss:0.6879, Train Acc:0.947000, Val Acc:0.6533
# Epoch:3, Loss:0.1145, Val Loss:0.5684, Train Acc:0.969000, Val Acc:0.8200
# Epoch:4, Loss:0.0979, Val Loss:0.6475, Train Acc:0.968000, Val Acc:0.8000
# Epoch:5, Loss:0.0838, Val Loss:1.0348, Train Acc:0.971000, Val Acc:0.7333
# Epoch:6, Loss:0.0660, Val Loss:0.7666, Train Acc:0.981000, Val Acc:0.7667
# Epoch:7, Loss:0.0551, Val Loss:0.6813, Train Acc:0.983000, Val Acc:0.8200
# Epoch:8, Loss:0.0545, Val Loss:0.4716, Train Acc:0.983000, Val Acc:0.8267
# Epoch:9, Loss:0.0488, Val Loss:0.9103, Train Acc:0.981000, Val Acc:0.7933
# Epoch:10, Loss:0.0204, Val Loss:0.8257, Train Acc:0.995000, Val Acc:0.8267
# Epoch:11, Loss:0.0043, Val Loss:0.9141, Train Acc:0.999000, Val Acc:0.8000
# Epoch:12, Loss:0.0078, Val Loss:0.7599, Train Acc:0.996000, Val Acc:0.8400
# Epoch:13, Loss:0.0550, Val Loss:0.6108, Train Acc:0.983000, Val Acc:0.8600
# Epoch:14, Loss:0.0285, Val Loss:0.4980, Train Acc:0.990000, Val Acc:0.8667
# Epoch:15, Loss:0.0195, Val Loss:0.9653, Train Acc:0.993000, Val Acc:0.8133
# Epoch:16, Loss:0.0207, Val Loss:0.6107, Train Acc:0.992000, Val Acc:0.8800
# Epoch:17, Loss:0.0090, Val Loss:0.7622, Train Acc:0.998000, Val Acc:0.8400
# Epoch:18, Loss:0.0035, Val Loss:0.9856, Train Acc:1.000000, Val Acc:0.8267
# Epoch:19, Loss:0.0038, Val Loss:1.0181, Train Acc:0.999000, Val Acc:0.8133
# Epoch:20, Loss:0.0008, Val Loss:0.9845, Train Acc:1.000000, Val Acc:0.8200
# Epoch:21, Loss:0.0003, Val Loss:1.0127, Train Acc:1.000000, Val Acc:0.8267
# Epoch:22, Loss:0.0002, Val Loss:1.0298, Train Acc:1.000000, Val Acc:0.8267
# Epoch:23, Loss:0.0002, Val Loss:0.9831, Train Acc:1.000000, Val Acc:0.8267
# Epoch:24, Loss:0.0001, Val Loss:1.0628, Train Acc:1.000000, Val Acc:0.8333
# Epoch:25, Loss:0.0001, Val Loss:1.0500, Train Acc:1.000000, Val Acc:0.8333

# %%
make_plots(train_losses, val_losses, train_accs, val_accs)

# %% [markdown]
# ## Experiment 4
# ### Training: 50 positive (50 real) and 950 negative
# ### Test: 75 positive (29 real + 46 generated) and 75 negative

# %%
train_real, test_real = train_test_split(real_wakes, train_size = 50/142, test_size=0.2, random_state=RS)
train_gen, test_gen = train_test_split(generated_wakes, train_size = 0.087, test_size=0.046, random_state=RS)
train_neg, test_neg = train_test_split(not_wakes, train_size = 950/3000, test_size = 75/3000, random_state = RS)
test_pos = np.append(test_real, test_gen, axis = 0)
train_pos = train_real
#train_pos = np.append(train_real, train_gen, axis = 0)
test_x = np.append(test_pos, test_neg, axis = 0)
train_x = np.append(train_pos, train_neg, axis = 0)
test_pos_y = np.concatenate((np.ones(test_pos.shape[0]).reshape(-1,1), np.zeros(test_pos.shape[0]).reshape(-1,1)), axis = 1)
test_neg_y = np.concatenate((np.zeros(test_neg.shape[0]).reshape(-1,1), np.ones(test_neg.shape[0]).reshape(-1,1)), axis = 1)
train_pos_y = np.concatenate((np.ones(train_pos.shape[0]).reshape(-1,1), np.zeros(train_pos.shape[0]).reshape(-1,1)), axis = 1)
train_neg_y = np.concatenate((np.zeros(train_neg.shape[0]).reshape(-1,1), np.ones(train_neg.shape[0]).reshape(-1,1)), axis = 1)
test_y = np.append(test_pos_y, test_neg_y, axis = 0)
train_y = np.append(train_pos_y, train_neg_y, axis = 0)
train_dataset = TensorDataset(torch.Tensor(train_x), torch.Tensor(train_y))
test_dataset = TensorDataset(torch.Tensor(test_x), torch.Tensor(test_y))

# %%
resnet_4 = None
resnet_4 = rn.ResNet18()
train_losses, val_losses, train_accs, val_accs = train_rn(resnet_4, train_dataset, test_dataset, num_epochs = num_epochs, learning_rate=1e-4)
# Out:
# Epoch:1, Loss:0.1507, Val Loss:1.0525, Train Acc:0.966000, Val Acc:0.6333
# Epoch:2, Loss:0.1183, Val Loss:0.9705, Train Acc:0.966000, Val Acc:0.6400
# Epoch:3, Loss:0.0874, Val Loss:1.1299, Train Acc:0.975000, Val Acc:0.6467
# Epoch:4, Loss:0.0691, Val Loss:1.0660, Train Acc:0.979000, Val Acc:0.6533
# Epoch:5, Loss:0.0779, Val Loss:1.1019, Train Acc:0.978000, Val Acc:0.6733
# Epoch:6, Loss:0.0497, Val Loss:1.2822, Train Acc:0.983000, Val Acc:0.6800
# Epoch:7, Loss:0.0534, Val Loss:1.0683, Train Acc:0.980000, Val Acc:0.7333
# Epoch:8, Loss:0.0274, Val Loss:0.9769, Train Acc:0.993000, Val Acc:0.7333
# Epoch:9, Loss:0.0301, Val Loss:0.9645, Train Acc:0.990000, Val Acc:0.7733
# Epoch:10, Loss:0.0293, Val Loss:1.3293, Train Acc:0.988000, Val Acc:0.7067
# Epoch:11, Loss:0.0058, Val Loss:1.8443, Train Acc:1.000000, Val Acc:0.6400
# Epoch:12, Loss:0.0049, Val Loss:1.2804, Train Acc:0.999000, Val Acc:0.7533
# Epoch:13, Loss:0.0216, Val Loss:1.9548, Train Acc:0.993000, Val Acc:0.6267
# Epoch:14, Loss:0.0275, Val Loss:1.7972, Train Acc:0.989000, Val Acc:0.6467
# Epoch:15, Loss:0.0096, Val Loss:1.4544, Train Acc:0.997000, Val Acc:0.7200
# Epoch:16, Loss:0.0017, Val Loss:1.9804, Train Acc:1.000000, Val Acc:0.6667
# Epoch:17, Loss:0.0005, Val Loss:1.9690, Train Acc:1.000000, Val Acc:0.6800
# Epoch:18, Loss:0.0009, Val Loss:1.9411, Train Acc:1.000000, Val Acc:0.6867
# Epoch:19, Loss:0.0003, Val Loss:1.8832, Train Acc:1.000000, Val Acc:0.6933
# Epoch:20, Loss:0.0003, Val Loss:1.8615, Train Acc:1.000000, Val Acc:0.7000
# Epoch:21, Loss:0.0002, Val Loss:1.9458, Train Acc:1.000000, Val Acc:0.6933
# Epoch:22, Loss:0.0001, Val Loss:2.0094, Train Acc:1.000000, Val Acc:0.6867
# Epoch:23, Loss:0.0001, Val Loss:2.0655, Train Acc:1.000000, Val Acc:0.6867
# Epoch:24, Loss:0.0001, Val Loss:2.0608, Train Acc:1.000000, Val Acc:0.7000
# Epoch:25, Loss:0.0001, Val Loss:1.9713, Train Acc:1.000000, Val Acc:0.7133

# %%
make_plots(train_losses, val_losses, train_accs, val_accs)

# %% [markdown]
# ## Experiment 5
# ### Training: 25 positive (25 real) and 975 negative
# ### Test: 75 positive (29 real + 46 generated) and 75 negative

# %%
train_real, test_real = train_test_split(real_wakes, train_size = 25/142, test_size=0.2, random_state=RS)
train_gen, test_gen = train_test_split(generated_wakes, train_size = 0.087, test_size=0.046, random_state=RS)
train_neg, test_neg = train_test_split(not_wakes, train_size = 975/3000, test_size = 75/3000, random_state = RS)
test_pos = np.append(test_real, test_gen, axis = 0)
train_pos = train_real
#train_pos = np.append(train_real, train_gen, axis = 0)
test_x = np.append(test_pos, test_neg, axis = 0)
train_x = np.append(train_pos, train_neg, axis = 0)
test_pos_y = np.concatenate((np.ones(test_pos.shape[0]).reshape(-1,1), np.zeros(test_pos.shape[0]).reshape(-1,1)), axis = 1)
test_neg_y = np.concatenate((np.zeros(test_neg.shape[0]).reshape(-1,1), np.ones(test_neg.shape[0]).reshape(-1,1)), axis = 1)
train_pos_y = np.concatenate((np.ones(train_pos.shape[0]).reshape(-1,1), np.zeros(train_pos.shape[0]).reshape(-1,1)), axis = 1)
train_neg_y = np.concatenate((np.zeros(train_neg.shape[0]).reshape(-1,1), np.ones(train_neg.shape[0]).reshape(-1,1)), axis = 1)
test_y = np.append(test_pos_y, test_neg_y, axis = 0)
train_y = np.append(train_pos_y, train_neg_y, axis = 0)
train_dataset = TensorDataset(torch.Tensor(train_x), torch.Tensor(train_y))
test_dataset = TensorDataset(torch.Tensor(test_x), torch.Tensor(test_y))

# %%
resnet_4 = None
resnet_4 = rn.ResNet18()
train_losses, val_losses, train_accs, val_accs = train_rn(resnet_4, train_dataset, test_dataset, num_epochs = num_epochs, learning_rate=1e-4)
# Out:
# Epoch:1, Loss:0.1251, Val Loss:1.3357, Train Acc:0.971000, Val Acc:0.5067
# Epoch:2, Loss:0.0947, Val Loss:1.4746, Train Acc:0.974000, Val Acc:0.5000
# Epoch:3, Loss:0.0737, Val Loss:1.1200, Train Acc:0.981000, Val Acc:0.6267
# Epoch:4, Loss:0.0552, Val Loss:1.3451, Train Acc:0.984000, Val Acc:0.7000
# Epoch:5, Loss:0.0591, Val Loss:1.5498, Train Acc:0.987000, Val Acc:0.6400
# Epoch:6, Loss:0.0240, Val Loss:1.5539, Train Acc:0.994000, Val Acc:0.6800
# Epoch:7, Loss:0.0409, Val Loss:1.0528, Train Acc:0.987000, Val Acc:0.7133
# Epoch:8, Loss:0.0358, Val Loss:2.1261, Train Acc:0.987000, Val Acc:0.6200
# Epoch:9, Loss:0.0143, Val Loss:1.5432, Train Acc:0.996000, Val Acc:0.7000
# Epoch:10, Loss:0.0067, Val Loss:2.0329, Train Acc:0.998000, Val Acc:0.6733
# Epoch:11, Loss:0.0068, Val Loss:2.0775, Train Acc:0.998000, Val Acc:0.6667
# Epoch:12, Loss:0.0084, Val Loss:2.0270, Train Acc:0.998000, Val Acc:0.6600
# Epoch:13, Loss:0.0172, Val Loss:2.2826, Train Acc:0.997000, Val Acc:0.6000
# Epoch:14, Loss:0.0476, Val Loss:1.8620, Train Acc:0.987000, Val Acc:0.6267
# Epoch:15, Loss:0.0096, Val Loss:1.9881, Train Acc:0.998000, Val Acc:0.6533
# Epoch:16, Loss:0.0018, Val Loss:2.4028, Train Acc:1.000000, Val Acc:0.6333
# Epoch:17, Loss:0.0047, Val Loss:2.6934, Train Acc:0.998000, Val Acc:0.6333
# Epoch:18, Loss:0.0017, Val Loss:2.4403, Train Acc:1.000000, Val Acc:0.6667
# Epoch:19, Loss:0.0006, Val Loss:2.8356, Train Acc:1.000000, Val Acc:0.6533
# Epoch:20, Loss:0.0004, Val Loss:3.1924, Train Acc:1.000000, Val Acc:0.6333
# Epoch:21, Loss:0.0005, Val Loss:2.8085, Train Acc:1.000000, Val Acc:0.6600
# Epoch:22, Loss:0.0002, Val Loss:2.8557, Train Acc:1.000000, Val Acc:0.6667
# Epoch:23, Loss:0.0004, Val Loss:2.9483, Train Acc:1.000000, Val Acc:0.6600
# Epoch:24, Loss:0.0001, Val Loss:3.1841, Train Acc:1.000000, Val Acc:0.6600
# Epoch:25, Loss:0.0000, Val Loss:3.2280, Train Acc:1.000000, Val Acc:0.6600

# %%
make_plots(train_losses, val_losses, train_accs, val_accs)

# %%
1
# Out:
# 1

# %% [markdown]
# ## Experiment: Noise in test data
# ### Training: 500 positive (113 real + 387 generated) and 500 negative
# ### Test: 75 positive (29 real + 46 generated) and 75 negative

# %%
correct_predictions = test_y_exp_1.argmax(1)

# %%
sigma = 0.1
noise = torch.randn_like(torch.Tensor(test_x_exp_1))*sigma
test_x_noisy = torch.Tensor(test_x_exp_1) + noise
pred_noisy = resnet_1(test_x_noisy.to(device)).argmax(1).cpu().numpy()
print("Sigma = 0.1, Test Accuracy: ", accuracy_score(correct_predictions, pred_noisy))
# Out:
# Sigma = 0.1, Test Accuracy:  0.68

# %%
sigma = 0.05
noise = torch.randn_like(torch.Tensor(test_x_exp_1))*sigma
test_x_noisy = torch.Tensor(test_x_exp_1) + noise
pred_noisy = resnet_1(test_x_noisy.to(device)).argmax(1).cpu().numpy()
print("Sigma = 0.05, Test Accuracy: ", accuracy_score(correct_predictions, pred_noisy))
# Out:
# Sigma = 0.05, Test Accuracy:  0.76

# %%
sigma = 0.01
noise = torch.randn_like(torch.Tensor(test_x_exp_1))*sigma
test_x_noisy = torch.Tensor(test_x_exp_1) + noise
pred_noisy = resnet_1(test_x_noisy.to(device)).argmax(1).cpu().numpy()
print("Sigma = 0.01, Test Accuracy: ", accuracy_score(correct_predictions, pred_noisy))
# Out:
# Sigma = 0.01, Test Accuracy:  0.9333333333333333

# %%
sigma = 0.005
noise = torch.randn_like(torch.Tensor(test_x_exp_1))*sigma
test_x_noisy = torch.Tensor(test_x_exp_1) + noise
pred_noisy = resnet_1(test_x_noisy.to(device)).argmax(1).cpu().numpy()
print("Sigma = 0.005, Test Accuracy: ", accuracy_score(correct_predictions, pred_noisy))
# Out:
# Sigma = 0.005, Test Accuracy:  0.9333333333333333

# %%
sigma = 0
noise = torch.randn_like(torch.Tensor(test_x_exp_1))*sigma
test_x_noisy = torch.Tensor(test_x_exp_1) + noise
pred_noisy = resnet_1(test_x_noisy.to(device)).argmax(1).cpu().numpy()
print("Sigma = 0, Test Accuracy: ", accuracy_score(correct_predictions, pred_noisy))
# Out:
# Sigma = 0, Test Accuracy:  0.92

# %%
1
# Out:
# 1
