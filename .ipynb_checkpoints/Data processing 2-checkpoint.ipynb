# %%
# YOUR CODE HERE
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture as GMM
from matplotlib.ticker import MaxNLocator
# %matplotlib inline


import random
import importlib
import Scripts.autoencoder as ae
import Scripts.wake_processing as wp
from scipy.stats import wasserstein_distance as w_dist

# %%
importlib.reload(ae)
importlib.reload(wp)
# Out:
# <module 'Scripts.wake_processing' from 'E:\\Studies\\Deep Water\\DeepWater\\Scripts\\wake_processing.py'>

# %% [markdown]
# ## Reading data

# %%
data_series = wp.get_files()

# %%
data_series.shape
# Out:
# (4, 30, 79023)

# %%
## Fixing shifted wake time stamps in data
# Special cases - no data - ignored
# ws:  2094960
# ws:  2418060
wake_start = wp.get_wakes()
new_ws = wake_start
for ws in wake_start:
    if ws not in set(data_series[0,-2,:]):
        if ws-12 in set(data_series[0,-2,:]):
            new_ws = np.append(new_ws, ws-12)

# %% [markdown]
# ## Train/test split

# %%
# 22 to 25 September for the test set.
cutoff = np.where(data_series[0,-2]<wp.date_to_stamp([9, 22, 0, 0]))[0][-1]
train_data_series = data_series[:,:-1,:cutoff]
test_data_series = data_series[:,:-1,cutoff:]
train_dn_series = data_series[:,:,:cutoff]
test_dn_series = data_series[:,:,cutoff:]

# %%
wake_samples_16 = wp.frames_by_timestamps(train_data_series, new_ws, depth = 16)

# %%
wake_samples = wp.frames_by_timestamps(train_data_series, new_ws)

# %%
#np.save('Data\\Wake data\\confirmed_wakes_16', wake_samples_16)

# %%
wp.make_heatmap(wake_samples_2[141,3,:-1,:], wake_samples_2[141,3,-1,:])

# %% [markdown]
# ## CNN autoencoder

# %%
model = None
model = ae.Autoencoder(final_kernel = 4)
model.double()
epochs = 60
outputs = ae.train_autoencoder(model, wake_samples[:,:,:16,:], num_epochs=epochs, batch_size = 5)
# Out:
# Epoch:1, Loss:0.3478
# Epoch:2, Loss:0.2140
# Epoch:3, Loss:0.1777
# Epoch:4, Loss:0.1688
# Epoch:5, Loss:0.1583
# Epoch:6, Loss:0.1598
# Epoch:7, Loss:0.1515
# Epoch:8, Loss:0.1425
# Epoch:9, Loss:0.1379
# Epoch:10, Loss:0.1297
# Epoch:11, Loss:0.1195
# Epoch:12, Loss:0.1062
# Epoch:13, Loss:0.0937
# Epoch:14, Loss:0.0920
# Epoch:15, Loss:0.0806
# Epoch:16, Loss:0.0747
# Epoch:17, Loss:0.0734
# Epoch:18, Loss:0.0700
# Epoch:19, Loss:0.0680
# Epoch:20, Loss:0.0651
# Epoch:21, Loss:0.0633
# Epoch:22, Loss:0.0596
# Epoch:23, Loss:0.0584
# Epoch:24, Loss:0.0572
# Epoch:25, Loss:0.0555
# Epoch:26, Loss:0.0538
# Epoch:27, Loss:0.0522
# Epoch:28, Loss:0.0527
# Epoch:29, Loss:0.0520
# Epoch:30, Loss:0.0521
# Epoch:31, Loss:0.0509
# Epoch:32, Loss:0.0510
# Epoch:33, Loss:0.0498
# Epoch:34, Loss:0.0488
# Epoch:35, Loss:0.0482
# Epoch:36, Loss:0.0488
# Epoch:37, Loss:0.0460
# Epoch:38, Loss:0.0485
# Epoch:39, Loss:0.0481
# Epoch:40, Loss:0.0479
# Epoch:41, Loss:0.0472
# Epoch:42, Loss:0.0457
# Epoch:43, Loss:0.0456
# Epoch:44, Loss:0.0453
# Epoch:45, Loss:0.0457
# Epoch:46, Loss:0.0450
# Epoch:47, Loss:0.0444
# Epoch:48, Loss:0.0445
# Epoch:49, Loss:0.0440
# Epoch:50, Loss:0.0439
# Epoch:51, Loss:0.0453
# Epoch:52, Loss:0.0436
# Epoch:53, Loss:0.0435
# Epoch:54, Loss:0.0432
# Epoch:55, Loss:0.0430
# Epoch:56, Loss:0.0427
# Epoch:57, Loss:0.0433
# Epoch:58, Loss:0.0433
# Epoch:59, Loss:0.0446
# Epoch:60, Loss:0.0434

# %%
test_reconst = ae.test_reconstruction(model, wake_samples[17,:,:16,:])

# %%
wake_samples[17,:,:16,:].shape
# Out:
# (4, 16, 60)

# %%
wp.make_heatmap(test_reconst[3], None)

# %%
wp.make_heatmap(wake_samples[17,3,:-1,:], None)

# %% [markdown]
# ## Positive samples with GMM and CNN

# %%
compressed_wakes = ae.compress_wakes(wake_samples_16, model)

# %%
gmm_cnn_data = np.array([w.flatten() for w in compressed_wakes])
pca_cnn = PCA(0.999, whiten=True)
data_cnn = pca_cnn.fit_transform(gmm_cnn_data)
n_components = np.arange(1, 60)
models = [GMM(n, covariance_type='full', random_state=0)
          for n in n_components]
aics = [model.fit(data_cnn).aic(data_cnn) for model in models]
plt.plot(n_components, aics)
plt.show()

# %%
gmm_cnn = GMM(21, covariance_type='full', random_state=44)
gmm_cnn.fit(data_cnn)
cnn_pca_seeds = gmm_cnn.sample(358)
cnn_seeds = pca_cnn.inverse_transform(cnn_pca_seeds[0])

# %%
cnn_seeds.shape
# Out:
# (358, 768)

# %%
decompressed_wakes = ae.decompress_wakes(cnn_seeds, model, comperssed_shape = compressed_wakes.shape[1:], depth = 16, points = 60)

# %%
wp.make_12_heatmaps(decompressed_wakes[:12,3, :, :], title =  'Generated Wake Samples (Beam 5)')

# %%
#np.save('Data\\Wake Data\\generated_wakes_16', decompressed_wakes)

# %%
train_data_series.shape
# Out:
# (4, 29, 69182)

# %% [markdown]
# ## Random negative samples

# %%
neg_series = train_data_series
for ws in new_ws:
    neg_series = neg_series[:,:,np.where((ws-1800 >= neg_series[0,-1]) | (neg_series[0,-1]  >= ws+1800))][:,:,0,:]

# %%
neg_ind = neg_series.shape[2]-60

# %%
rand_fs = np.random.randint(neg_ind, size=500)

# %%
neg_samples = []
for fs in rand_fs:
    neg_samples.append(neg_series[:,:16, fs:fs+60])

# %%
neg_samples = np.array(neg_samples)

# %%
wp.make_heatmap(neg_samples[5,3,:], None)

# %% [markdown]
# ## Random negative samples (day)

# %%
neg_dn_series = train_dn_series
for ws in new_ws:
    neg_dn_series = neg_dn_series[:,:,np.where((ws-1800 >= neg_dn_series[0,-2]) | (neg_dn_series[0,-2]  >= ws+1800))][:,:,0,:]

# %%
neg_dn_series.shape
# Out:
# (4, 30, 55346)

# %%
np.where(data_series[0,-1] == 1)[0].shape
# Out:
# (43323,)

# %%
np.where(neg_dn_series[0,-1] == 1)[0].shape
# Out:
# (30344,)

# %%
day_data = neg_dn_series[:,:,np.where(neg_dn_series[0,-1] == 1)[0]]

# %%
rand_day = np.random.randint(day_data.shape[2], size=1000)

# %%
neg_day_samples = []
for fs in rand_day:
    neg_day_samples.append(neg_dn_series[:,:16, fs:fs+60])
neg_day_samples = np.array(neg_day_samples)

# %%
neg_day_samples.shape
# Out:
# (1000, 4, 16, 60)

# %%
wp.make_heatmap(neg_day_samples[3,3,:], None)

# %%
np.save('Data\Wake data\\negative_day_samples_16', neg_day_samples)

# %% [markdown]
# ## Beam comparison

# %%
blue = train_data_series[:,:-1,:].min()
flat_blue = (np.ones((16,60))*blue).flatten()

# %%
wake_samples_16.shape
# Out:
# (142, 4, 17, 60)

# %%
wasdist =[[],[],[],[]]
for w in wake_samples_16[:,:,:-1,:]:
    for i in range(4):
        wasdist[i].append(w_dist(w[i,:,:].flatten(), flat_blue))
wasdist_agg =[[],[],[],[]]
temp = [0,0,0,0]
for i in range(142):
    for j in range(4):
        wasdist_agg[j].append(wasdist[j][i] + temp[j])
        temp[j] += wasdist[j][i]

# %%
plt.figure(figsize=(12,8))
plt.plot(wasdist[0], 'c', label = 'Beam 1')
plt.plot(wasdist[1], 'm', label = 'Beam 3')
plt.plot(wasdist[2], 'y', label = 'Beam 4')
plt.plot(wasdist[3], 'k', label = 'Beam 5 (central)')
plt.title('Wasserstein distance to still water (confirmed wakes)')
plt.ylabel('Wasserstein distance')
plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(wasdist_agg[0], 'c', label = 'Beam 1')
plt.plot(wasdist_agg[1], 'm', label = 'Beam 3')
plt.plot(wasdist_agg[2], 'y', label = 'Beam 4')
plt.plot(wasdist_agg[3], 'k', label = 'Beam 5 (central)')
plt.title('Aggregated Wasserstein distance to still water (confirmed wakes)')
plt.ylabel('Wasserstein distance')
plt.legend()
plt.show()

# %%
wasdist_rand =[[],[],[],[]]
for w in neg_samples[:100,:,:-1,:]:
    for i in range(4):
        wasdist_rand[i].append(w_dist(w[i,:,:].flatten(), flat_blue))

wasdist_rand_agg =[[],[],[],[]]
temp = [0,0,0,0]
for i in range(100):
    for j in range(4):
        wasdist_rand_agg[j].append(wasdist_rand[j][i] + temp[j])
        temp[j] += wasdist_rand[j][i]

# %%
plt.figure(figsize=(12,8))
plt.plot(wasdist_rand[0], 'c', label = 'Beam 1')
plt.plot(wasdist_rand[1], 'm', label = 'Beam 3')
plt.plot(wasdist_rand[2], 'y', label = 'Beam 4')
plt.plot(wasdist_rand[3], 'k', label = 'Beam 5 (central)')
plt.title('Wasserstein distance to still water (random negative samples)')
plt.ylabel('Wasserstein distance')
plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(wasdist_rand_agg[0], 'c', label = 'Beam 1')
plt.plot(wasdist_rand_agg[1], 'm', label = 'Beam 3')
plt.plot(wasdist_rand_agg[2], 'y', label = 'Beam 4')
plt.plot(wasdist_rand_agg[3], 'k', label = 'Beam 5 (central)')
plt.title('Aggregated Wasserstein distance to still water (random negative samples)')
plt.ylabel('Wasserstein distance')
plt.legend()
plt.show()

# %%
neg_samples.shape
# Out:
# (500, 4, 16, 60)

# %%
decompressed_wakes.shape
# Out:
# (358, 4, 16, 60)

# %%
wake_samples_16[:,:,:-1,:].shape
# Out:
# (142, 4, 16, 60)

# %%
wp.make_heatmap(wake_samples_16[0,3,:-1,:], None)

# %%
wp.make_heatmap(decompressed_wakes[0,3,:,:], None)

# %%
wp.make_heatmap(neg_samples[0,3,:,:], None)

# %% [markdown]
# ## Wasserstein distances

# %%
w_total = 0
for w1 in wake_samples_16[:,:,:-1,:]:
    for w2 in decompressed_wakes[:]:
        for i in range(4):
            w_total+=w_dist(w1[i,:].flatten(), w2[i,:].flatten())
print('Average wasserstein distance generated vs. real wakes:', w_total/(4*wake_samples.shape[0]*decompressed_wakes.shape[0]))
# Out:
# Average wasserstein distance generated vs. real wakes: 0.05390032951534382

# %%
w_total = 0
for w1 in wake_samples_16[:,:,:-1,:]:
    for w2 in neg_samples[:,:,:,:]:
        for i in range(4):
            w_total+=w_dist(w1[i,:].flatten(), w2[i,:].flatten())
print('Average wasserstein distance random frames vs. real wakes:', w_total/(4*wake_samples.shape[0]*neg_samples.shape[0]))
# Out:
# Average wasserstein distance random frames vs. real wakes: 0.05541568041183052

# %%
w_total = 0
for w1 in neg_samples[:,:,:,:]:
    for w2 in decompressed_wakes[:]:
        for i in range(4):
            w_total+=w_dist(w1[i,:].flatten(), w2[i,:].flatten())
print('Average wasserstein distance generated vs. random frames:', w_total/(4*neg_samples.shape[0]*decompressed_wakes.shape[0]))
# Out:
# Average wasserstein distance generated vs. random frames: 0.05148244047723699
